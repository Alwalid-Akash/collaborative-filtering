# %%
import pandas as pd

# %%
scores = pd.read_csv('scores.csv')
question_bank = pd.read_csv('question_bank.csv')
scores = pd.merge(question_bank,scores).drop(['genres','timestamp'],axis=1)
print(scores.shape)
scores.head()
# Out:
# (2000, 4)
#    questionId                                  question  userId  score
# 0           1  When will you hand ____ your assignment?       1      3
# 1           1  When will you hand ____ your assignment?       2      0
# 2           1  When will you hand ____ your assignment?       3      2
# 3           1  When will you hand ____ your assignment?       4      3
# 4           1  When will you hand ____ your assignment?       5      2

# %%
userScores=scores.pivot_table(index=['userId'],columns=['question'],values='score')
userScores.head()
# Out:
# question   The Opium war id held between which two countries?  \
# userId
# 1                                                         3
# 2                                                         3
# 3                                                         2
# 4                                                         1
# 5                                                         3
#
# question  'Not bene' means –  \
# userId
# 1                          1
# 2                          0
# 3                          5
# 4                          4
# 5                          3
#
# question  A constitutional monarchy provides what power to a monarch?  \
# userId
# 1                                                         5
# 2                                                         2
# 3                                                         3
# 4                                                         1
# 5                                                         0
#
# question  A speed limit is the _________ legal speed that you can travel on the road.  \
# userId
# 1                                                         2
# 2                                                         1
# 3                                                         0
# 4                                                         0
# 5                                                         1
#
# question  AFTER: BEFORE:   \
# userId
# 1                       2
# 2                       2
# 3                       0
# 4                       3
# 5                       3
#
# question  After _____________ smoking, they let the cigarette fall on the wood floor.  \
# userId
# 1                                                         2
# 2                                                         3
# 3                                                         0
# 4                                                         4
# 5                                                         4
#
# question  All of us are devoted ________ one another.  \
# userId
# 1                                                   4
# 2                                                   4
# 3                                                   4
# 4                                                   1
# 5                                                   1
#
# question  An interest group hires lobbyists to  \
# userId
# 1                                            5
# 2                                            3
# 3                                            5
# 4                                            4
# 5                                            3
#
# question  Antonym of DENIGRATE is _____________?  CATTLE : DROVE : :  ...  \
# userId                                                                ...
# 1                                              0                   2  ...
# 2                                              0                   0  ...
# 3                                              2                   0  ...
# 4                                              3                   5  ...
# 5                                              0                   3  ...
#
# question  Who is known as Man of Blood and Iron?  \
# userId
# 1                                              0
# 2                                              1
# 3                                              0
# 4                                              1
# 5                                              1
#
# question  Who is the First Test Tube Twins Babies in the World?  \
# userId
# 1                                                         1
# 2                                                         1
# 3                                                         1
# 4                                                         1
# 5                                                         0
#
# question  Who made the first chocolate bar?  \
# userId
# 1                                         5
# 2                                         4
# 3                                         0
# 4                                         0
# 5                                         0
#
# question  Who said that " Man is a political animal"?  \
# userId
# 1                                                   5
# 2                                                   3
# 3                                                   4
# 4                                                   0
# 5                                                   1
#
# question  Who was among the famous Roman poets?  \
# userId
# 1                                             3
# 2                                             5
# 3                                             0
# 4                                             5
# 5                                             2
#
# question  Who was the modern world's first woman head of government?  \
# userId
# 1                                                         5
# 2                                                         2
# 3                                                         5
# 4                                                         4
# 5                                                         3
#
# question  Whose winter residence did potala palace serve as till 1959?  \
# userId
# 1                                                         1
# 2                                                         4
# 3                                                         1
# 4                                                         3
# 5                                                         5
#
# question  Young Italy movement by led by two revolutionaries, One was Mazzini" and Other was?"  \
# userId
# 1                                                         0
# 2                                                         5
# 3                                                         2
# 4                                                         4
# 5                                                         0
#
# question  ___________you wake me up so early on a Sunday?  \
# userId
# 1                                                       3
# 2                                                       1
# 3                                                       3
# 4                                                       0
# 5                                                       1
#
# question  _________the rain forests is very important, if we do not want the flora and fauna found there to become extinct.
# userId
# 1                                                         5
# 2                                                         5
# 3                                                         1
# 4                                                         4
# 5                                                         2
#
# [5 rows x 100 columns]

# %%
print("Before: ",userScores.shape)
#userRatings.fillna(0,inplace=True)
print("After: ",userScores.shape)
# Out:
# Before:  (20, 100)
# After:  (20, 100)

# %%
corrMatrix = userScores.corr(method='pearson')
corrMatrix.head()
print(corrMatrix.head())
# Out:
# question                                             The Opium war id held between which two countries?  \
# question
#  The Opium war id held between which two countr...                                           1.000000
# 'Not bene' means –                                                                          -0.107472
# A constitutional monarchy provides what power t...                                           0.373395
# A speed limit is the _________ legal speed that...                                           0.090998
# AFTER: BEFORE:                                                                               0.127082
#
# question                                            'Not bene' means –  \
# question
#  The Opium war id held between which two countr...           -0.107472
# 'Not bene' means –                                            1.000000
# A constitutional monarchy provides what power t...           -0.246692
# A speed limit is the _________ legal speed that...           -0.099388
# AFTER: BEFORE:                                               -0.491679
#
# question                                            A constitutional monarchy provides what power to a monarch?  \
# question
#  The Opium war id held between which two countr...                                           0.373395
# 'Not bene' means –                                                                          -0.246692
# A constitutional monarchy provides what power t...                                           1.000000
# A speed limit is the _________ legal speed that...                                           0.122669
# AFTER: BEFORE:                                                                              -0.096956
#
# question                                            A speed limit is the _________ legal speed that you can travel on the road.  \
# question
#  The Opium war id held between which two countr...                                           0.090998
# 'Not bene' means –                                                                          -0.099388
# A constitutional monarchy provides what power t...                                           0.122669
# A speed limit is the _________ legal speed that...                                           1.000000
# AFTER: BEFORE:                                                                               0.249786
#
# question                                            AFTER: BEFORE:   \
# question
#  The Opium war id held between which two countr...         0.127082
# 'Not bene' means –                                        -0.491679
# A constitutional monarchy provides what power t...        -0.096956
# A speed limit is the _________ legal speed that...         0.249786
# AFTER: BEFORE:                                             1.000000
#
# question                                            After _____________ smoking, they let the cigarette fall on the wood floor.  \
# question
#  The Opium war id held between which two countr...                                          -0.265998
# 'Not bene' means –                                                                          -0.051977
# A constitutional monarchy provides what power t...                                          -0.499295
# A speed limit is the _________ legal speed that...                                           0.005096
# AFTER: BEFORE:                                                                               0.124397
#
# question                                            All of us are devoted ________ one another.  \
# question
#  The Opium war id held between which two countr...                                     0.256235
# 'Not bene' means –                                                                     0.169850
# A constitutional monarchy provides what power t...                                     0.239888
# A speed limit is the _________ legal speed that...                                    -0.282067
# AFTER: BEFORE:                                                                        -0.504976
#
# question                                            An interest group hires lobbyists to  \
# question
#  The Opium war id held between which two countr...                             -0.330255
# 'Not bene' means –                                                             -0.305386
# A constitutional monarchy provides what power t...                              0.055153
# A speed limit is the _________ legal speed that...                             -0.103780
# AFTER: BEFORE:                                                                  0.063360
#
# question                                            Antonym of DENIGRATE is _____________?  \
# question
#  The Opium war id held between which two countr...                               -0.357635
# 'Not bene' means –                                                                0.264371
# A constitutional monarchy provides what power t...                               -0.094695
# A speed limit is the _________ legal speed that...                               -0.131685
# AFTER: BEFORE:                                                                    0.055463
#
# question                                            CATTLE : DROVE : :  ...  \
# question                                                                ...
#  The Opium war id held between which two countr...           -0.202721  ...
# 'Not bene' means –                                           -0.344628  ...
# A constitutional monarchy provides what power t...           -0.198444  ...
# A speed limit is the _________ legal speed that...           -0.071847  ...
# AFTER: BEFORE:                                                0.669818  ...
#
# question                                            Who is known as Man of Blood and Iron?  \
# question
#  The Opium war id held between which two countr...                                0.016817
# 'Not bene' means –                                                                0.417987
# A constitutional monarchy provides what power t...                               -0.283078
# A speed limit is the _________ legal speed that...                                0.059923
# AFTER: BEFORE:                                                                   -0.112840
#
# question                                            Who is the First Test Tube Twins Babies in the World?  \
# question
#  The Opium war id held between which two countr...                                          -0.032815
# 'Not bene' means –                                                                           0.316578
# A constitutional monarchy provides what power t...                                          -0.177124
# A speed limit is the _________ legal speed that...                                           0.025865
# AFTER: BEFORE:                                                                               0.154417
#
# question                                            Who made the first chocolate bar?  \
# question
#  The Opium war id held between which two countr...                           0.241585
# 'Not bene' means –                                                          -0.210340
# A constitutional monarchy provides what power t...                           0.078416
# A speed limit is the _________ legal speed that...                           0.204169
# AFTER: BEFORE:                                                               0.206553
#
# question                                            Who said that " Man is a political animal"?  \
# question
#  The Opium war id held between which two countr...                                     0.383023
# 'Not bene' means –                                                                    -0.295099
# A constitutional monarchy provides what power t...                                     0.361136
# A speed limit is the _________ legal speed that...                                     0.201263
# AFTER: BEFORE:                                                                         0.116821
#
# question                                            Who was among the famous Roman poets?  \
# question
#  The Opium war id held between which two countr...                               0.236568
# 'Not bene' means –                                                               0.096259
# A constitutional monarchy provides what power t...                               0.041288
# A speed limit is the _________ legal speed that...                               0.031191
# AFTER: BEFORE:                                                                  -0.080641
#
# question                                            Who was the modern world's first woman head of government?  \
# question
#  The Opium war id held between which two countr...                                          -0.201945
# 'Not bene' means –                                                                           0.207624
# A constitutional monarchy provides what power t...                                          -0.043268
# A speed limit is the _________ legal speed that...                                          -0.326760
# AFTER: BEFORE:                                                                              -0.388508
#
# question                                            Whose winter residence did potala palace serve as till 1959?  \
# question
#  The Opium war id held between which two countr...                                           0.079071
# 'Not bene' means –                                                                          -0.134148
# A constitutional monarchy provides what power t...                                          -0.221364
# A speed limit is the _________ legal speed that...                                          -0.001604
# AFTER: BEFORE:                                                                               0.195768
#
# question                                            Young Italy movement by led by two revolutionaries, One was Mazzini" and Other was?"  \
# question
#  The Opium war id held between which two countr...                                          -0.037803
# 'Not bene' means –                                                                          -0.219390
# A constitutional monarchy provides what power t...                                          -0.242062
# A speed limit is the _________ legal speed that...                                          -0.278640
# AFTER: BEFORE:                                                                               0.458312
#
# question                                            ___________you wake me up so early on a Sunday?  \
# question
#  The Opium war id held between which two countr...                                         0.193847
# 'Not bene' means –                                                                         0.240257
# A constitutional monarchy provides what power t...                                         0.207922
# A speed limit is the _________ legal speed that...                                         0.292844
# AFTER: BEFORE:                                                                            -0.168922
#
# question                                            _________the rain forests is very important, if we do not want the flora and fauna found there to become extinct.
# question
#  The Opium war id held between which two countr...                                          -0.092217
# 'Not bene' means –                                                                          -0.244218
# A constitutional monarchy provides what power t...                                          -0.027591
# A speed limit is the _________ legal speed that...                                          -0.157127
# AFTER: BEFORE:                                                                               0.039707
#
# [5 rows x 100 columns]

# %%
def get_similar_questions(question,score):
    similar_scores = corrMatrix[question]*(score-2.5)
    similar_scores = similar_scores.sort_values(ascending=False)
    print(type(similar_scores))
   
    return similar_scores

# %%
english_love = [("When will you hand ____ your assignment?",5),
                 ("There is something wonderful _______ him.",1),
              
                ("Where is the 'Pearl Harbour' located?",3)]

similar_quesrions = pd.DataFrame()

for question,score in english_love:
    similar_questions = similar_questions.append(get_similar_questions(question,score),ignore_index = True)
         
similar_questions.head(20)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
#     The Opium war id held between which two countries?  'Not bene' means –  \
# 0                                           0.354852              0.144389
# 1                                           0.415482             -0.216393
# 2                                          -0.504881             -0.285128
# 3                                           0.174459              0.056642
# 4                                          -0.356649              0.069690
# 5                                           0.130535             -0.175042
#
#    A constitutional monarchy provides what power to a monarch?  \
# 0                                           0.061932
# 1                                          -0.358496
# 2                                          -0.095588
# 3                                          -0.287654
# 4                                          -0.467897
# 5                                           0.260337
#
#    A speed limit is the _________ legal speed that you can travel on the road.  \
# 0                                           0.046787
# 1                                           0.086790
# 2                                          -0.066207
# 3                                           0.282286
# 4                                           0.307461
# 5                                           0.036104
#
#    AFTER: BEFORE:   \
# 0        -0.120962
# 1         0.065797
# 2         0.507507
# 3        -0.073675
# 4         0.485870
# 5         0.116950
#
#    After _____________ smoking, they let the cigarette fall on the wood floor.  \
# 0                                          -0.051822
# 1                                           0.212533
# 2                                           0.287509
# 3                                           0.199901
# 4                                           0.059029
# 5                                          -0.130208
#
#    All of us are devoted ________ one another.  \
# 0                                    -0.133303
# 1                                     0.034017
# 2                                     0.060549
# 3                                    -0.342808
# 4                                    -0.309307
# 5                                    -0.021226
#
#    An interest group hires lobbyists to  \
# 0                             -0.209477
# 1                              0.108784
# 2                             -0.079089
# 3                             -0.633061
# 4                              0.220372
# 5                             -0.120464
#
#    Antonym of DENIGRATE is _____________?  CATTLE : DROVE : :  ...  \
# 0                               -0.081990           -0.036673  ...
# 1                               -0.240612            0.061550  ...
# 2                                0.099312            0.513192  ...
# 3                                0.609121            0.304696  ...
# 4                                0.051885            0.626603  ...
# 5                                0.010682           -0.043001  ...
#
#    Who is known as Man of Blood and Iron?  \
# 0                                0.137603
# 1                               -0.377302
# 2                                0.074621
# 3                               -0.259984
# 4                                0.079969
# 5                                0.040611
#
#    Who is the First Test Tube Twins Babies in the World?  \
# 0                                           0.150302
# 1                                          -0.329015
# 2                                           0.254416
# 3                                           0.190242
# 4                                           0.240757
# 5                                          -0.218459
#
#    Who made the first chocolate bar?  \
# 0                           0.110114
# 1                          -0.151510
# 2                           0.642779
# 3                          -0.386495
# 4                           0.299444
# 5                           0.113605
#
#    Who said that " Man is a political animal"?  \
# 0                                    -0.155333
# 1                                    -0.278056
# 2                                     0.135406
# 3                                     0.378902
# 4                                     0.026020
# 5                                     0.085711
#
#    Who was among the famous Roman poets?  \
# 0                               1.500000
# 1                               0.543039
# 2                              -0.624604
# 3                              -0.049302
# 4                              -0.072791
# 5                              -0.003179
#
#    Who was the modern world's first woman head of government?  \
# 0                                           0.189366
# 1                                           0.092345
# 2                                          -0.127255
# 3                                          -0.380246
# 4                                           0.162515
# 5                                           0.039541
#
#    Whose winter residence did potala palace serve as till 1959?  \
# 0                                          -0.137476
# 1                                           0.420095
# 2                                           0.271478
# 3                                           0.755020
# 4                                          -0.092896
# 5                                           0.075590
#
#    Young Italy movement by led by two revolutionaries, One was Mazzini" and Other was?"  \
# 0                                           0.310112
# 1                                           0.644270
# 2                                           0.106452
# 3                                          -0.283082
# 4                                           0.471887
# 5                                           0.021281
#
#    ___________you wake me up so early on a Sunday?  \
# 0                                        -0.101735
# 1                                         0.084965
# 2                                         0.009452
# 3                                         0.258655
# 4                                         0.052675
# 5                                        -0.046993
#
#    _________the rain forests is very important, if we do not want the flora and fauna found there to become extinct.
# 0                                           0.336972
# 1                                           0.555474
# 2                                           0.461035
# 3                                          -0.041931
# 4                                          -0.433363
# 5                                           0.065853
#
# [6 rows x 100 columns]

# %%
similar_questions.sum().sort_values(ascending=False).head(20);

# %%
gk_lover = [("Who was among the famous Roman poets?",4),
            ("Russian revolutionary, who founded the Communist Party was",4),
            ("Which state to be 1st state to legalize mask-wearing?",1)]
similar_questions = pd.DataFrame()
for question,score in gk_lover:
    similar_questions = similar_questions.append(get_similar_questions(question,score),ignore_index = True)

     similar_questions.head(10)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
#     The Opium war id held between which two countries?  'Not bene' means –  \
# 0                                           0.354852              0.144389
# 1                                           0.415482             -0.216393
# 2                                          -0.504881             -0.285128
#
#    A constitutional monarchy provides what power to a monarch?  \
# 0                                           0.061932
# 1                                          -0.358496
# 2                                          -0.095588
#
#    A speed limit is the _________ legal speed that you can travel on the road.  \
# 0                                           0.046787
# 1                                           0.086790
# 2                                          -0.066207
#
#    AFTER: BEFORE:   \
# 0        -0.120962
# 1         0.065797
# 2         0.507507
#
#    After _____________ smoking, they let the cigarette fall on the wood floor.  \
# 0                                          -0.051822
# 1                                           0.212533
# 2                                           0.287509
#
#    All of us are devoted ________ one another.  \
# 0                                    -0.133303
# 1                                     0.034017
# 2                                     0.060549
#
#    An interest group hires lobbyists to  \
# 0                             -0.209477
# 1                              0.108784
# 2                             -0.079089
#
#    Antonym of DENIGRATE is _____________?  CATTLE : DROVE : :  ...  \
# 0                               -0.081990           -0.036673  ...
# 1                               -0.240612            0.061550  ...
# 2                                0.099312            0.513192  ...
#
#    Who is known as Man of Blood and Iron?  \
# 0                                0.137603
# 1                               -0.377302
# 2                                0.074621
#
#    Who is the First Test Tube Twins Babies in the World?  \
# 0                                           0.150302
# 1                                          -0.329015
# 2                                           0.254416
#
#    Who made the first chocolate bar?  \
# 0                           0.110114
# 1                          -0.151510
# 2                           0.642779
#
#    Who said that " Man is a political animal"?  \
# 0                                    -0.155333
# 1                                    -0.278056
# 2                                     0.135406
#
#    Who was among the famous Roman poets?  \
# 0                               1.500000
# 1                               0.543039
# 2                              -0.624604
#
#    Who was the modern world's first woman head of government?  \
# 0                                           0.189366
# 1                                           0.092345
# 2                                          -0.127255
#
#    Whose winter residence did potala palace serve as till 1959?  \
# 0                                          -0.137476
# 1                                           0.420095
# 2                                           0.271478
#
#    Young Italy movement by led by two revolutionaries, One was Mazzini" and Other was?"  \
# 0                                           0.310112
# 1                                           0.644270
# 2                                           0.106452
#
#    ___________you wake me up so early on a Sunday?  \
# 0                                        -0.101735
# 1                                         0.084965
# 2                                         0.009452
#
#    _________the rain forests is very important, if we do not want the flora and fauna found there to become extinct.
# 0                                           0.336972
# 1                                           0.555474
# 2                                           0.461035
#
# [3 rows x 100 columns]

# %%
similar_questions.sum().sort_values(ascending=False).head(20);
